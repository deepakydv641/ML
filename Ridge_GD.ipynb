# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes

# %%
x,y=load_diabetes(return_X_y=True)

# %%
x.shape
# Out:
# (442, 10)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (353, 10)

# %%
from sklearn.linear_model import SGDRegressor
sgd=SGDRegressor(max_iter=500,learning_rate='constant',eta0=0.01,alpha=0.0001)

# %%
sgd.fit(x_train,y_train)
# Out:
# SGDRegressor(learning_rate='constant', max_iter=500)

# %%
sgd.coef_
# Out:
# array([  52.41126334, -130.43664866,  417.2291516 ,  279.82093993,
#         -26.63903599,  -70.00489023, -197.19717641,  147.08972741,
#         318.20101844,  142.64855034])

# %%
sgd.intercept_
# Out:
# array([151.17784457])

# %%
res=sgd.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,res)
# Out:
# 0.4554525888868435

# %% [markdown]
# Now i will scikit learn Ridge class

# %% [raw]
# from sklearn.linear_model import Ridge
# ri=Ridge(alpha=0.0001,solver='sparse_cg')

# %%
ri.fit(x_train,y_train)
ri.coef_
# Out:
# array([  37.96896724, -241.90045951,  542.5935044 ,  347.604089  ,
#        -919.86392313,  508.99592077,  158.21377539,  273.68991994,
#         731.71430609,   48.78692048])

# %%
ri.intercept_
# Out:
# np.float64(151.3451787421406)

# %%
result=ri.predict(x_test)

# %%
r2_score(y_test,result)
# Out:
# 0.4526998153190007

# %%
class Myridg:

    def __init__(self,learning_rate,epochs,alpha):
        self.coef_=None
        self.intercept_=None
        self.alpha=alpha
        self.lr=learning_rate
        self.epochs=epochs

    def fit(self,x_train,Y_train):
        self.coef_=np.ones(x_train.shape[1])
        self.intercept_=0
        thetha=np.insert(self.coef_,0,self.intercept_)
        for i in range(self.epochs):
            thetha_der = np.dot(x_train.T,x_train).dot(thetha) - np.dot(X_train.T,y_train) + self.alpha*thetha
            thetha = thetha - self.learning_rate*thetha_der
        self.coef_=theta[1:]
        self.intercept_=theta[0]

    def predict(self,x_test):
        return np.dot(x_test,self.coef_)+self.intercept_

# %%
mr=Myridg(0.01,500,0.001)

# %%
mr.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 mr.fit(x_train,y_train)
#
# Cell In[32], line 15, in Myridg.fit(self, x_train, Y_train)
#      13 thetha=np.insert(self.coef_,0,self.intercept_)
#      14 for i in range(self.epochs):
# ---> 15     thetha_der = np.dot(x_train.T,x_train).dot(thetha) - np.dot(X_train.T,y_train) + self.alpha*thetha
#      16     thetha = thetha - self.learning_rate*thetha_der
#      17 self.coef_=theta[1:]
#
# ValueError: shapes (10,10) and (11,) not aligned: 10 (dim 1) != 11 (dim 0)
