# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

path=r"C:\Users\deepa\OneDrive\Desktop\ipl2024 Matches.csv"

# %%
df=pd.read_csv(path)

# %%
df.sample(5)
# Out:
#     id           date     team1      team2 toss_winner decision  first_score  \
# 5    6  March 25,2024    Punjab   Banglore    Banglore    Field          176
# 38  39  April 23,2024   Chennai    Lucknow     Lucknow    Field          210
# 71  72    May 22,2024  Banglore  Rajasthan   Rajasthan    Field          172
# 14  15   April 2,2024   Lucknow   Banglore    Banglore    Field          181
# 55  56     May 7,2024     Delhi  Rajasthan   Rajasthan    Field          221
#
#     first_wkts  second_score  second_wkts     winner  player_of_the_match  \
# 5            6           178            6   Banglore          Virat Kohli
# 38           4           213            4    Lucknow       Marcus Stoinis
# 71           8           174            6  Rajasthan  Ravichandran Ashwin
# 14           5           153           10    Lucknow         Mayank Yadav
# 55           8           201            8      Delhi        Kuldeep Yadav
#
#            most_runs            most_wkts
# ...
